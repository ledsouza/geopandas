# %% [markdown]
# # Desafio - Aula 1

# %%
url = 'https://github.com/alura-cursos/curso_geopandas/raw/main/dados/Estado_SP.shp'

# %%
import geopandas as gpd

# %%
sp = gpd.read_file(url)

# %%
sp.plot()
# Out:
# <Axes: >

# %%
sp.head()
# Out:
#     CD_MUN            NM_MUN SIGLA_UF  AREA_KM2  \
# 0  3500105        Adamantina       SP   411.987
# 1  3500204            Adolfo       SP   211.055
# 2  3500303             Aguaí       SP   474.554
# 3  3500402    Águas da Prata       SP   142.673
# 4  3500501  Águas de Lindóia       SP    60.126
#
#                                             geometry
# 0  POLYGON ((-51.09557 -21.57029, -51.09617 -21.5...
# 1  POLYGON ((-49.61249 -21.26110, -49.61249 -21.2...
# 2  POLYGON ((-47.01254 -22.00527, -47.01219 -22.0...
# 3  POLYGON ((-46.71875 -21.95837, -46.71878 -21.9...
# 4  POLYGON ((-46.61761 -22.51172, -46.61864 -22.5...

# %%
sp = sp[sp['NM_MUN']=='São Paulo']

# %%
sp.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Desafio - Aula 2

# %%
url_m = 'https://github.com/alura-cursos/curso_geopandas/raw/main/dados/SIRGAS_SHP_estacaometro_point.shp'

# %%
metro = gpd.read_file(url_m)

# %%
metro.head()
# Out:
#   emt_empres emt_situac emt_linha               emt_nome  \
# 0      METRO   OPERANDO  VERMELHA   CORINTHIANS-ITAQUERA
# 1      METRO   OPERANDO  VERMELHA            ARTUR ALVIM
# 2      METRO   OPERANDO  VERMELHA              PATRIARCA
# 3      METRO   OPERANDO  VERMELHA  GUILHERMINA-ESPERANÇA
# 4      METRO   OPERANDO  VERMELHA           VILA MATILDE
#
#                          geometry
# 0  POINT (349839.380 7395675.047)
# 1  POINT (348457.592 7395884.165)
# 2  POINT (346732.712 7396874.617)
# 3  POINT (345181.965 7397070.921)
# 4  POINT (343708.935 7396765.736)

# %%
metro.plot()
# Out:
# <Axes: >

# %%
url_c = 'https://github.com/alura-cursos/curso_geopandas/raw/main/dados/SIRGAS_SHP_TEMA_-_CULTURA_TEATRO-CINEMA-SHOW.shp'

# %%
cultura = gpd.read_file(url_c)

# %%
cultura.head()
# Out:
#     eq_esfera          eq_tipo                              eq_nome  \
# 0  PARTICULAR  SALAS DE CINEMA  CANTAREIRA NORTESHOPPING - CINEFLIX
# 1  PARTICULAR  SALAS DE CINEMA  CANTAREIRA NORTESHOPPING - CINEFLIX
# 2  PARTICULAR  SALAS DE CINEMA  CANTAREIRA NORTESHOPPING - CINEFLIX
# 3  PARTICULAR  SALAS DE CINEMA  CANTAREIRA NORTESHOPPING - CINEFLIX
# 4  PARTICULAR  SALAS DE CINEMA  CANTAREIRA NORTESHOPPING - CINEFLIX
#
#                                   eq_enderec eq_telefon        eq_bairro  \
# 0  AV. RAIMUNDO PEREIRA DE MAGALHÃES, 11.001       None  JARDIM PIRITUBA
# 1  AV. RAIMUNDO PEREIRA DE MAGALHÃES, 11.001       None  JARDIM PIRITUBA
# 2  AV. RAIMUNDO PEREIRA DE MAGALHÃES, 11.001       None  JARDIM PIRITUBA
# 3  AV. RAIMUNDO PEREIRA DE MAGALHÃES, 11.001       None  JARDIM PIRITUBA
# 4  AV. RAIMUNDO PEREIRA DE MAGALHÃES, 11.001       None  JARDIM PIRITUBA
#
#   eq_cep eq_cd_esfe eq_cd_tipo eq_id  ... eq_cd_subp        eq_subpref  \
# 0   None          4          7   617  ...         02  PIRITUBA-JARAGUA
# 1   None          4          7   618  ...         02  PIRITUBA-JARAGUA
# 2   None          4          7   619  ...         02  PIRITUBA-JARAGUA
# 3   None          4          7   620  ...         02  PIRITUBA-JARAGUA
# 4   None          4          7   621  ...         02  PIRITUBA-JARAGUA
#
#   eq_regiao5 eq_regiao8 eq_espaco eq_inaugur eq_assento eq_acessib eq_estacio  \
# 0      NORTE    NORTE 2    SALA 1   20160427        158       None       None
# 1      NORTE    NORTE 2    SALA 2   20160427        199       None       None
# 2      NORTE    NORTE 2    SALA 3   20160427        161       None       None
# 3      NORTE    NORTE 2    SALA 4   20160427        131       None       None
# 4      NORTE    NORTE 2    SALA 5   20160427        122       None       None
#
#                          geometry
# 0  POINT (323985.870 7406117.770)
# 1  POINT (323985.870 7406117.770)
# 2  POINT (323985.870 7406117.770)
# 3  POINT (323985.870 7406117.770)
# 4  POINT (323985.870 7406117.770)
#
# [5 rows x 24 columns]

# %%
sp.crs
# Out:
# <Geographic 2D CRS: EPSG:4674>
# Name: SIRGAS 2000
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Latin America - Central America and South America - onshore and offshore. Brazil - onshore and offshore.
# - bounds: (-122.19, -59.87, -25.28, 32.72)
# Datum: Sistema de Referencia Geocentrico para las AmericaS 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
sp = sp.to_crs('+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=m +no_defs')

# %%
sp.crs
# Out:
# <Bound CRS: +proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0, ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: Transformation from unknown to WGS84
# - method: Position Vector transformation (geog2D domain)
# Datum: Unknown based on GRS 1980 ellipsoid using towgs84=0,0,0,0,0,0,0
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich
# Source CRS: unknown

# %%
# não retorna nada pois não crs definido
metro.crs

# %%
metro = metro.set_crs('+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=m +no_defs')

# %%
metro.crs
# Out:
# <Bound CRS: +proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0, ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: Transformation from unknown to WGS84
# - method: Position Vector transformation (geog2D domain)
# Datum: Unknown based on GRS 1980 ellipsoid using towgs84=0,0,0,0,0,0,0
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich
# Source CRS: unknown

# %%
cultura.crs

# %%
cultura = cultura.set_crs('+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=m +no_defs')

# %% [markdown]
# # Desafio - Aula 3

# %%
base = sp.plot(color='white', edgecolor='black', figsize=(15,8))
metro.plot(ax=base, color='blue', markersize=5)
cultura.plot(ax=base, color='red', alpha=0.2, markersize=5)
# Out:
# <Axes: >
